# %% [markdown]
# <a href="https://colab.research.google.com/github/imrangis/practice/blob/main/ckUpload_Shapefile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade xee
# !pip insatll -u geemap
# Out:
# Requirement already satisfied: xee in /usr/local/lib/python3.12/dist-packages (0.1.0)
# Requirement already satisfied: xarray[parallel] in /usr/local/lib/python3.12/dist-packages (from xee) (2025.12.0)
# Requirement already satisfied: earthengine-api>=1.6.12 in /usr/local/lib/python3.12/dist-packages (from xee) (1.7.22)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from xee) (3.7.2)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from xee) (2.4.0)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from xee) (2.1.2)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (3.10.1)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (2.194.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (2.47.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (0.3.1)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (0.31.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->xee) (2.32.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj->xee) (2026.4.22)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from shapely->xee) (2.0.2)
# Requirement already satisfied: packaging>=24.1 in /usr/local/lib/python3.12/dist-packages (from xarray[parallel]->xee) (26.1)
# Requirement already satisfied: pandas>=2.2 in /usr/local/lib/python3.12/dist-packages (from xarray[parallel]->xee) (2.2.2)
# Requirement already satisfied: dask[complete] in /usr/local/lib/python3.12/dist-packages (from xarray[parallel]->xee) (2026.3.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->xee) (2.30.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->xee) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->xee) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.4.1->earthengine-api>=1.6.12->xee) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=1.6.12->xee) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray[parallel]->xee) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray[parallel]->xee) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2->xarray[parallel]->xee) (2026.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (8.3.3)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (2025.3.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (6.0.3)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (0.12.1)
# Requirement already satisfied: pyarrow>=16.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (18.1.0)
# Requirement already satisfied: lz4>=4.3.2 in /usr/local/lib/python3.12/dist-packages (from dask[complete]; extra == "parallel"->xarray[parallel]->xee) (4.4.5)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api>=1.6.12->xee) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api>=1.6.12->xee) (2.8.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api>=1.6.12->xee) (1.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api>=1.6.12->xee) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api>=1.6.12->xee) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->earthengine-api>=1.6.12->xee) (2.5.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->xee) (1.74.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->xee) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->xee) (1.27.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask[complete]; extra == "parallel"->xarray[parallel]->xee) (1.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.6.12->xee) (0.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray[parallel]->xee) (1.17.0)
# Requirement already satisfied: distributed<2026.3.1,>=2026.3.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]->xarray[parallel]->xee) (2026.3.0)
# Requirement already satisfied: bokeh>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from dask[complete]->xarray[parallel]->xee) (3.8.2)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.12/dist-packages (from dask[complete]->xarray[parallel]->xee) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee) (2.20.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee) (11.3.0)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1.0->dask[complete]->xarray[parallel]->xee) (2026.3.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from distributed<2026.3.1,>=2026.3.0->dask[complete]->xarray[parallel]->xee) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from distributed<2026.3.1,>=2026.3.0->dask[complete]->xarray[parallel]->xee) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from distributed<2026.3.1,>=2026.3.0->dask[complete]->xarray[parallel]->xee) (2.4.0)
# Requirement already satisfied: tblib!=3.2.0,!=3.2.1,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from distributed<2026.3.1,>=2026.3.0->dask[complete]->xarray[parallel]->xee) (3.2.2)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from distributed<2026.3.1,>=2026.3.0->dask[complete]->xarray[parallel]->xee) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.10.3->dask[complete]->xarray[parallel]->xee) (3.0.3)
# ERROR: unknown command "insatll" - maybe you meant "install"

# %%
import ee
import geemap

# %%
ee.Authenticate()

# %%
ee.Authenticate()
ee.Initialize(
    project='red-function-469007-f2',
    opt_url='https://earthengine-highvolume.googleapis.com'
)

# %%
map =geemap.Map()
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright', transp…

# %%
point = map.draw_last_feature.geometry()
point
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ee.Geometry({
#   "functionInvocationValue": {
#     "functionName": "Feature.geometry",
#     "arguments": {
#       "feature": {
#         "functionInvocationValue": {
#           "functionName": "Feature",
#           "arguments": {
#             "geometry": {
#               "functionInvocationValue": {
#                 "functionName": "GeometryConstructors.Point",
#                 "arguments": {
#                   "coordinates": {
#                     "constantValue": [
#                       89.355065,
#                       22.917923
#                     ]
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# })

# %%
bd = (
    ee.FeatureCollection("USDOS/LSIB_SIMPLE/2017")
    .filterBounds(point)
    .geometry().simplify(1000)
)
bd
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ee.Geometry({
#   "functionInvocationValue": {
#     "functionName": "Geometry.simplify",
#     "arguments": {
#       "geometry": {
#         "functionInvocationValue": {
#           "functionName": "Collection.geometry",
#           "arguments": {
#             "collection": {
#               "functionInvocationValue": {
#                 "functionName": "Collection.filter",
#                 "arguments": {
#                   "collection": {
#                     "functionInvocationValue": {
#                       "functionName": "Collection.loadTable",
#                       "arguments": {
#                         "tableId": {
#                           "constantValue": "USDOS/LSIB_SIMPLE/2017"
#                         }
#                       }
#                     }
#                   },
#                   "filter": {
#                     "functionInvocationValue": {
#                       "functionName": "Filter.intersects",
#                       "arguments": {
#                         "leftField": {
#                           "constantValue": ".all"
#                         },
#                         "rightValue": {
#                           "functionInvocationValue": {
#                             "functionName": "Feature",
#                             "arguments": {
#                               "geometry": {
#                                 "functionInvocationValue": {
#                                   "functionName": "Feature.geometry",
#                                   "arguments": {
#                                     "feature": {
#                                       "functionInvocationValue": {
#                                         "functionName": "Feature",
#                                         "arguments": {
#                                           "geometry": {
#                                             "functionInvocationValue": {
#                                               "functionName": "GeometryConstructors.Point",
#                                               "arguments": {
#                                                 "coordinates": {
#                                                   "constantValue": [
#                                                     89.355065,
#                                                     22.917923
#                                                   ]
#                                                 }
#                                               }
#                                             }
#                                           }
#                                         }
#                                       }
#                                     }
#                                   }
#                                 }
#                               }
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       },
#       "maxError": {
#         "functionInvocationValue": {
#           "functionName": "ErrorMargin",
#           "arguments": {
#             "value": {
#               "constantValue": 1000
#             }
#           }
#         }
#       }
#     }
#   }
# })

# %%
map.addLayer(bd)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
